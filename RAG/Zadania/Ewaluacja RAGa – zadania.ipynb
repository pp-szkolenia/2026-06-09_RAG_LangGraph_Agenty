# %% [markdown]
# # Ewaluacja RAGa – zadania

# %% [markdown]
# 1. Wczytaj plik `.json` z poprzedniego zadania i dla poszczególnych test case'ów (pytań zadanych modelowi) policz wartości metryk:
# - `ContextualPrecisionMetric`
# - `ContextualRecallMetric`
# - `ContextualRelevancyMetric`
#
# ---
#
# **Uwaga:** dla metryki `ContextualRelevancy` nie sprawdzaj wszystkich pytań (wystarczy jedno) i nie wykonuj requestów w trybie asynchronicznym. Ta ewaluacja wymaga wykonania wiele requestów do API OpenAI co może wiązać się z dłuższym czasem oczekiwania i kosztami. Wykonanie requestów asynchronicznie może skończyć się błędem.
#
# Wynika to z tego, że poszczególne stwierdzenia, które występują w pozyskanych dokumentach (a jest ich wiele) muszą zostać porównane z zadanym pytaniem.
#
# ---
# (czas: 20 min.)

# %%
# ...

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# 2. W analogiczny sposób policz wartości kolejnych metryk dla poszczególnych test case'ów:
# - `AnswerRelevancyMetric`
# - `FaithfulnessMetric`
# - `Correctness`
#
# ---
#
# (czas: 15 min.)

# %%
# ...
