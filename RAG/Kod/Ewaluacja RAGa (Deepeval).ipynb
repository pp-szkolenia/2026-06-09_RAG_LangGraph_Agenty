# %% [markdown]
# # Ewaluacja RAGa
#
# Jednym z narzędzi do ewaluacji systemów RAG i LLMów w ogólności jest biblioteka `deepeval`
#
# https://docs.confident-ai.com/docs/getting-started

# %% [markdown]
# ## Quickstart
#
# Aby dokonać ewaluacji działania systemu opartego o LLM, np. RAG używamy klasy `LLMTestCase`.
#
# Test case'y bazują na następujących parametrach:
# - `input` (prompt użytkownika)
# - `actual_output` (rzeczywista odpowiedź modelu)
# - `expected_output` (oczekiwana odpowiedź modelu)
# - `retrieval_context` (kontekst pozyskany z bazy wektorowej)
#
# Parametrów tych jest więcej, ale w kontekście metryk dla RAGa będziemy używać wyłącznie powyższych.

# %%
from dotenv import load_dotenv

from deepeval.metrics import AnswerRelevancyMetric
from deepeval.test_case import LLMTestCase
from deepeval import evaluate
from deepeval.evaluate import AsyncConfig, DisplayConfig

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# Dokumentacja `LLMTestCase`: https://docs.confident-ai.com/docs/evaluation-test-cases

# %%
test_case = LLMTestCase(
    input="What if these shoes don't fit?",
    actual_output="We offer a 30-day full refund at no extra cost.",
    expected_output="You're eligible for a 30 day refund at no extra cost.",
    retrieval_context=["All customers are eligible for a 30 day full refund at no extra cost."]
)

# %%
answer_relevancy_metric = AnswerRelevancyMetric(threshold=0.5, model="gpt-4o")

# %%
import os
os.environ["DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE"] = "100"

# %%
result = evaluate([test_case], [answer_relevancy_metric])
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-4o, strict=False, async_mode=True)...
# Output()
# Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "/home/patryk/.local/share/uv/python/cpython-3.13.12-linux-x86_64-gnu/lib/python3.13/asyncio/events.py",
# line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x7d24ac13e1c0> is already entered
# Task was destroyed but it is pending!
# task: <Task pending name='Task-6' coro=<_async_in_context.<locals>.run_in_context() done, defined at
# /home/patryk/CloudDrive/Szkolenia/Realizacje/EITT/2026-06-09_RAG_LangGraph_Agenty/.venv/lib/python3.13/site-package
# s/ipykernel/utils.py:57> wait_for=<Task pending name='Task-7' coro=<Kernel.shell_main() running at
# /home/patryk/CloudDrive/Szkolenia/Realizacje/EITT/2026-06-09_RAG_LangGraph_Agenty/.venv/lib/python3.13/site-package
# s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at
# /home/patryk/CloudDrive/Szkolenia/Realizacje/EITT/2026-06-09_RAG_LangGraph_Agenty/.venv/lib/python3.13/site-package
# s/zmq/eventloop/zmqstream.py:563]>
# /home/patryk/CloudDrive/Szkolenia/Realizacje/EITT/2026-06-09_RAG_LangGraph_Agenty/.venv/lib/python3.13/site-package
# s/pydantic/_internal/_generate_schema.py:816: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   {*fields.keys(), *computed_fields.keys()},
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-7' coro=<Kernel.shell_main() running at
# /home/patryk/CloudDrive/Szkolenia/Realizacje/EITT/2026-06-09_RAG_LangGraph_Agenty/.venv/lib/python3.13/site-package
# s/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 DeepEval Evaluation Results                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_0 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Aggregate Metrics                                                                                               │
# │                                                                                                                 │
# │  Metric                                ┃ Average Score                  ┃ Pass Rate             ┃ Total         │
# │ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━ │
# │  Answer Relevancy                      │ 1.00                           │ 100.00%               │ 1             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351833;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 5.38s | token cost: 0.0036900000000000006 USD)
# » Test Results (1 total tests):
#    » Pass Rate: 100.0% | Passed: 1 | Failed: 0
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
result
# Out:
# EvaluationResult(test_results=[TestResult(name='test_case_0', success=True, metrics_data=[MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='The score is 1.00 because the response perfectly addressed the concern about shoe fit without any irrelevant information. Great job!', strict_mode=False, evaluation_model='gpt-4o', error=None, evaluation_cost=0.0036900000000000006, verbose_logs='Statements:\n[\n    "We offer a 30-day full refund.",\n    "There is no extra cost."\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    },\n    {\n        "verdict": "idk",\n        "reason": "The statement about no extra cost is ambiguous as it doesn\'t directly address the concern about shoe fit but could imply no cost for returns."\n    }\n]')], conversational=False, index=0, multimodal=False, input="What if these shoes don't fit?", actual_output='We offer a 30-day full refund at no extra cost.', expected_output="You're eligible for a 30 day refund at no extra cost.", context=None, retrieval_context=['All customers are eligible for a 30 day full refund at no extra cost.'], turns=None, metadata=None)], confident_link=None, test_run_id=None)

# %%
result.test_results[0].metrics_data[0]
# Out:
# MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='The score is 1.00 because the response perfectly addressed the concern about shoe fit without any irrelevant information. Great job!', strict_mode=False, evaluation_model='gpt-4o', error=None, evaluation_cost=0.0036900000000000006, verbose_logs='Statements:\n[\n    "We offer a 30-day full refund.",\n    "There is no extra cost."\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    },\n    {\n        "verdict": "idk",\n        "reason": "The statement about no extra cost is ambiguous as it doesn\'t directly address the concern about shoe fit but could imply no cost for returns."\n    }\n]')

# %%
result.test_results[0].metrics_data[0]
# Out:
# MetricData(name='Answer Relevancy', threshold=0.5, success=True, score=1.0, reason='The score is 1.00 because the response perfectly addressed the concern about shoe fit without any irrelevant information. Great job!', strict_mode=False, evaluation_model='gpt-4o', error=None, evaluation_cost=0.0036900000000000006, verbose_logs='Statements:\n[\n    "We offer a 30-day full refund.",\n    "There is no extra cost."\n] \n \nVerdicts:\n[\n    {\n        "verdict": "yes",\n        "reason": null\n    },\n    {\n        "verdict": "idk",\n        "reason": "The statement about no extra cost is ambiguous as it doesn\'t directly address the concern about shoe fit but could imply no cost for returns."\n    }\n]')

# %%
result.test_results[0].metrics_data[0].score
# Out:
# 1.0

# %% [markdown]
# ## Metryki
#
# W bibliotece `deepeval` występuje 5 metryk, które mogą być pomocne do zastosowań związanych z RAG:
#
# **retrieval**
# - `ContextualPrecisionMetric`
# - `ContextualRecallMetric`
# - `ContextualRelevancyMetric`
#
# **generation**
# - `AnswerRelevancyMetric`
# - `FaithfulnessMetric`
#
#
# Oprócz tego istnieje również możliwość tworzenia customowych metryk za pomocą klasy `GEval`.

# %% [markdown]
# ### Retrieval
#
# #### `ContextualPrecisionMetric`
#
# Ocenia, czy reranker w retrieverze umieszcza bardziej istotne fragmenty w kontekście wyszukiwania wyżej niż fragmenty mniej istotne.
#
# Innymi słowy sprawdzamy, czy kolejność pozyskanych dokumentów jest optymalna w kontekście zadanego pytania.
#
# https://docs.confident-ai.com/docs/metrics-contextual-precision
#
# ---
#
# **Zestawiamy:** kolejność elementów w `retrieval_context` i `model_input`

# %%
from deepeval.metrics import ContextualPrecisionMetric


model_input = "What if these shoes don't fit?"
actual_output = "It doesn't matter."
expected_output = "It doesn't matter as well."

retrieval_context_1 = ["All customers are eligible for a 30 day full refund at no extra cost.",
                       "For each pair of shoes bought, you get a 10% discount for the next purchase."]

retrieval_context_2 = ["For each pair of shoes bought, you get a 10% discount for the next purchase.",
                       "All customers are eligible for a 30 day full refund at no extra cost."]

retrieval_context_3 = ["At our shop we sell shoes",
                       "For each pair of shoes bought, you get a 10% discount for the next purchase."]


metric = ContextualPrecisionMetric(
    threshold=0.7,
    model="gpt-4o"
)

test_cases = []
for retrieval_context in [retrieval_context_1, retrieval_context_2, retrieval_context_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output,
        expected_output=expected_output,
        retrieval_context=retrieval_context
    )

    test_cases.append(test_case)

# %%
len(test_cases)
# Out:
# 3

# %% [markdown]
# Aby policzyć wartość metryki należy wywołać funkcję `evaluate()` przekazując do niej m.in. poniższe argumenty:
# - listę przypadków testowych – może być to lista jednoelementowa
# - listę metryk – również może być jednoelementowa
# - `print_results` (opcjonalnie) – do kontroli *verbosity*
# - `run_async` (opcjonalnie) – wywołanie asynchroniczne przyspieszy działanie kodu, ale nie zapewnia nam określonej kolejności wyników

# %%
result = evaluate(
    test_cases, [metric],
    async_config=AsyncConfig(run_async=True),
    display_config=DisplayConfig(print_results=True)
)
# Out:
# ✨ You're running DeepEval's latest Contextual Precision Metric! (using gpt-4o, strict=False, async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ 🚀 DeepEval Evaluation Results                                                                                  │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ ✅ test_case_0 (Passed 1 metrics)                                                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ test_case_1                                                                                                 │
# │  ├──   Input:              What if these shoes don't fit?                                                       │
# │  │     Actual Output:      It doesn't matter.                                                                   │
# │  │     Expected Output:    It doesn't matter as well.                                                           │
# │  └── Metrics                                                                                                    │
# │       Status ┃ Metric               ┃ Score ┃ Threshold ┃ Reason                                                │
# │      ━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  │
# │        FAIL  │ Contextual Precision │ 0.50  │ 0.70      │ The score is 0.50 because the second node, ranked     │
# │              │                      │       │           │ second, is relevant as it states 'All customers are   │
# │              │                      │       │           │ eligible for a 30 day full refund at no extra         │
# │              │                      │       │           │ cost,' which directly addresses the concern about     │
# │              │                      │       │           │ shoes not fitting. However, the first node, ranked    │
# │              │                      │       │           │ first, is irrelevant as it mentions 'For each pair    │
# │              │                      │       │           │ of shoes bought, you get a 10% discount for the       │
# │              │                      │       │           │ next purchase,' which does not relate to the issue    │
# │              │                      │       │           │ of shoes not fitting. The presence of an irrelevant   │
# │              │                      │       │           │ node ranked higher than a relevant one results in a   │
# │              │                      │       │           │ moderate score.                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ❌ test_case_2                                                                                                 │
# │  ├──   Input:              What if these shoes don't fit?                                                       │
# │  │     Actual Output:      It doesn't matter.                                                                   │
# │  │     Expected Output:    It doesn't matter as well.                                                           │
# │  └── Metrics                                                                                                    │
# │       Status ┃ Metric               ┃ Score ┃ Threshold ┃ Reason                                                │
# │      ━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  │
# │        FAIL  │ Contextual Precision │ 0.00  │ 0.70      │ The score is 0.00 because both nodes in the           │
# │              │                      │       │           │ retrieval contexts are irrelevant to the input        │
# │              │                      │       │           │ question about shoes not fitting. The first node,     │
# │              │                      │       │           │ ranked 1, provides the context 'At our shop we sell   │
# │              │                      │       │           │ shoes,' which does not address the concern of shoes   │
# │              │                      │       │           │ not fitting. Similarly, the second node, ranked 2,    │
# │              │                      │       │           │ offers the context 'For each pair of shoes bought,    │
# │              │                      │       │           │ you get a 10% discount for the next purchase,'        │
# │              │                      │       │           │ which is unrelated to the issue of shoes not          │
# │              │                      │       │           │ fitting. As a result, the retrieval failed to         │
# │              │                      │       │           │ prioritize relevant information, leading to a score   │
# │              │                      │       │           │ of 0.00.                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Aggregate Metrics                                                                                               │
# │                                                                                                                 │
# │  Metric                                     ┃ Average Score                ┃ Pass Rate           ┃ Total        │
# │ ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━ │
# │  Contextual Precision                       │ 0.50                         │ 33.33%              │ 3            │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351835;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 5.45s | token cost: 0.01441 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 33.33% | Passed: 1 | Failed: 2
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Model input:", result.test_results[0].input, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nContext:\n{test_result.retrieval_context}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Model input: What if these shoes don't fit?
# =================================================================
#
#
# score: 0.0
# threshold: 0.7
# success: False
# ------------
# Context:
# ['At our shop we sell shoes', 'For each pair of shoes bought, you get a 10% discount for the next purchase.']
# ------------
# Reason:
# The score is 0.00 because both nodes in the retrieval contexts are irrelevant to the input question about shoes not fitting. The first node, ranked 1, provides the context 'At our shop we sell shoes,' which does not address the concern of shoes not fitting. Similarly, the second node, ranked 2, offers the context 'For each pair of shoes bought, you get a 10% discount for the next purchase,' which is unrelated to the issue of shoes not fitting. As a result, the retrieval failed to prioritize relevant information, leading to a score of 0.00.
#
# ======
#
# score: 0.5
# threshold: 0.7
# success: False
# ------------
# Context:
# ['For each pair of shoes bought, you get a 10% discount for the next purchase.', 'All customers are eligible for a 30 day full refund at no extra cost.']
# ------------
# Reason:
# The score is 0.50 because the second node, ranked second, is relevant as it states 'All customers are eligible for a 30 day full refund at no extra cost,' which directly addresses the concern about shoes not fitting. However, the first node, ranked first, is irrelevant as it mentions 'For each pair of shoes bought, you get a 10% discount for the next purchase,' which does not relate to the issue of shoes not fitting. The presence of an irrelevant node ranked higher than a relevant one results in a moderate score.
#
# ======
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Context:
# ['All customers are eligible for a 30 day full refund at no extra cost.', 'For each pair of shoes bought, you get a 10% discount for the next purchase.']
# ------------
# Reason:
# The score is 1.00 because the relevant node, ranked first, directly addresses the input by stating "All customers are eligible for a 30 day full refund at no extra cost," which perfectly aligns with the concern about shoes not fitting. The irrelevant node, ranked second, mentions "a 10% discount for the next purchase," which does not relate to the fitting issue, ensuring it is appropriately ranked lower. Great job on maintaining perfect precision!
#
# ======

# %% [markdown]
# #### `ContextualRecallMetric`
#
# Ocenia, czy retriever potrafi poprawnie dobrać właściwe informacje do tego co jest w oczekiwanej odpowiedzi.
#
# https://docs.confident-ai.com/docs/metrics-contextual-recall
#
# ---
#
# **Zestawiamy:** `retrieval_context` oraz `expected_output`

# %%
from deepeval.metrics import ContextualRecallMetric


model_input = "It doesn't matter"
actual_output = "It doesn't matter as well"
expected_output = "You are eligible for a 30 day full refund at no extra cost."

retrieval_context_1 = ["All customers are eligible for a 30 day full refund at no extra cost. This sentence is irrlevant. Nothing important. Hello world.",
                       "At our shop we sell shoes"]
retrieval_context_2 = ["All customers are eligible for a 30 day full refund at no extra cost."]
retrieval_context_3 = ["For each pair of shoes bought, you get a 10% discount for the next purchase.", "At our shop we sell shoes"]


metric = ContextualRecallMetric(
    threshold=0.7,
    model="gpt-4o"
)


test_cases = []
for retrieval_context in [retrieval_context_1, retrieval_context_2, retrieval_context_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output,
        expected_output=expected_output,
        retrieval_context=retrieval_context
    )

    test_cases.append(test_case)

# %%
result = evaluate(test_cases, [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))
# Out:
# ✨ You're running DeepEval's latest Contextual Recall Metric! (using gpt-4o, strict=False, async_mode=False)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351839;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 9.66s | token cost: 0.00938 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 66.67% | Passed: 2 | Failed: 1
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Expected output:", result.test_results[0].expected_output, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nContext:\n{test_result.retrieval_context}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Expected output: You are eligible for a 30 day full refund at no extra cost.
# =================================================================
#
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Context:
# ['All customers are eligible for a 30 day full refund at no extra cost. This sentence is irrlevant. Nothing important. Hello world.', 'At our shop we sell shoes']
# ------------
# Reason:
# The score is 1.00 because the expected output perfectly aligns with the information from the 1st node in the retrieval context. Great job!
#
# ======
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Context:
# ['All customers are eligible for a 30 day full refund at no extra cost.']
# ------------
# Reason:
# The score is 1.00 because the expected output perfectly aligns with the information from the 1st node in the retrieval context, ensuring complete accuracy and relevance. Great job!
#
# ======
#
# score: 0.0
# threshold: 0.7
# success: False
# ------------
# Context:
# ['For each pair of shoes bought, you get a 10% discount for the next purchase.', 'At our shop we sell shoes']
# ------------
# Reason:
# The score is 0.00 because the expected output sentence about a 30-day full refund cannot be linked to any node in the retrieval context, which focuses on discounts and shoe sales without mentioning refunds.
#
# ======

# %% [markdown]
# #### `ContextualRelevancyMetric`
#
# Ocenia jaki odsetek fragmentów zwróconych przez retriever dotyczy tego, czego dotyczy prompt wejściowy.
#
# https://docs.confident-ai.com/docs/metrics-contextual-relevancy
#
# ---
#
# **Zestawiamy:** proporcję relewantnych tekstów w `retrieval_context` w odniesieniu do `model_input`

# %%
from deepeval.metrics import ContextualRelevancyMetric


model_input = "What if these shoes don't fit?"
actual_output = "It doesn't matter"
expected_output = "It doesn't matter as well"

retrieval_context_1 = ["All customers are eligible for a 30 day full refund at no extra cost. This sentence is irrlevant. Nothing important. Hello world.", "At our shop we sell shoes. . This sentence is irrlevant. Nothing important. Hello world."]
retrieval_context_2 = ["All customers are eligible for a 30 day full refund at no extra cost."]
retrieval_context_3 = ["For each pair of shoes bought, you get a 10% discount for the next purchase.", "At our shop we sell shoes"]


metric = ContextualRelevancyMetric(
    threshold=0.7,
    model="gpt-4o"
)



test_cases = []
for retrieval_context in [retrieval_context_1, retrieval_context_2, retrieval_context_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output,
        expected_output=expected_output,
        retrieval_context=retrieval_context
    )

    test_cases.append(test_case)

# %%
result = evaluate(test_cases, [metric],
                  async_config=AsyncConfig(run_async=False),
                  display_config=DisplayConfig(print_results=False))
# Out:
# ✨ You're running DeepEval's latest Contextual Relevancy Metric! (using gpt-4o, strict=False, async_mode=False)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351843;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 12.41s | token cost: 0.0159075 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 33.33% | Passed: 1 | Failed: 2
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Model input:", result.test_results[0].input, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nContext:\n{test_result.retrieval_context}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Model input: What if these shoes don't fit?
# =================================================================
#
#
# score: 0.25
# threshold: 0.7
# success: False
# ------------
# Context:
# ['All customers are eligible for a 30 day full refund at no extra cost. This sentence is irrlevant. Nothing important. Hello world.', 'At our shop we sell shoes. . This sentence is irrlevant. Nothing important. Hello world.']
# ------------
# Reason:
# The score is 0.25 because the majority of the retrieval context, such as 'This sentence is irrelevant' and 'Hello world,' does not relate to the question about shoe fit. However, the statement 'All customers are eligible for a 30 day full refund at no extra cost' is relevant as it addresses potential concerns about shoe fit.
#
# ======
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Context:
# ['All customers are eligible for a 30 day full refund at no extra cost.']
# ------------
# Reason:
# The score is 1.00 because the retrieval context perfectly addresses the input by providing a clear and relevant solution: 'All customers are eligible for a 30 day full refund at no extra cost.' Great job on ensuring the information is spot on!
#
# ======
#
# score: 0.0
# threshold: 0.7
# success: False
# ------------
# Context:
# ['For each pair of shoes bought, you get a 10% discount for the next purchase.', 'At our shop we sell shoes']
# ------------
# Reason:
# The score is 0.00 because none of the statements in the retrieval context address the concern about shoe fit, such as 'For each pair of shoes bought, you get a 10% discount for the next purchase.' and 'At our shop we sell shoes.' These statements focus on promotions and general sales rather than fit issues.
#
# ======

# %% [markdown]
# ### Generation

# %% [markdown]
# #### `AnswerRelevancyMetric`
#
# Określa na ile odpowiedź modelu jest adekwatna w odniesieniu do inputu użytkownika.
#
# https://docs.confident-ai.com/docs/metrics-answer-relevancy
#
# ---
#
# **Zestawiamy:** `model_input` i `actual_output`.

# %%
from deepeval.metrics import AnswerRelevancyMetric


model_input = "What if these shoes don't fit?"

actual_output_1 = "We offer a 30-day full refund at no extra cost."
actual_output_2 = "If the shoes don't fit, ..."
actual_output_3 = "Hello world"

metric = AnswerRelevancyMetric(
    threshold=0.7,
    model="gpt-4o"
)


test_cases = []
for actual_output in [actual_output_1, actual_output_2, actual_output_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output
    )

    test_cases.append(test_case)

# %%
result = evaluate(test_cases, [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))
# Out:
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using gpt-4o, strict=False, async_mode=False)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351847;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 10.41s | token cost: 0.0105725 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 66.67% | Passed: 2 | Failed: 1
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Model input:", result.test_results[0].input, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nActual output:\n{test_result.actual_output}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Model input: What if these shoes don't fit?
# =================================================================
#
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Actual output:
# We offer a 30-day full refund at no extra cost.
# ------------
# Reason:
# The score is 1.00 because the response perfectly addresses the concern about shoe fit without any irrelevant information. Great job staying focused and relevant!
#
# ======
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Actual output:
# If the shoes don't fit, ...
# ------------
# Reason:
# The score is 1.00 because the response perfectly addresses the concern about shoe fit without any irrelevant information. Great job!
#
# ======
#
# score: 0.0
# threshold: 0.7
# success: False
# ------------
# Actual output:
# Hello world
# ------------
# Reason:
# The score is 0.00 because the output included a generic greeting 'Hello world' which is completely unrelated to the concern about shoe fit. The response did not address the question at all, leading to a score of zero.
#
# ======

# %% [markdown]
# #### `FaithfulnessMetric`
#
# Określa czy odpowiedź modelu odnosi się w do pozyskanego z bazy kotenkstu.
#
# https://docs.confident-ai.com/docs/metrics-faithfulness
#
# ---
#
# **Zestawiamy:** `actual_output` i `retrieval_context`.

# %%
from deepeval.metrics import FaithfulnessMetric


model_input = "It doesn't matter"
actual_output = "We offer a 30-day full refund at no extra cost."

retrieval_context_1 = ["All customers are eligible for a 30 day full refund at no extra cost."]
retrieval_context_2 = ["At our shop we sell shoes."]
retrieval_context_3 = ["It's not possible to offer any refund to the customer."]

metric = FaithfulnessMetric(
    threshold=0.7,
    model="gpt-4o"
)


test_cases = []
for retrieval_context in [retrieval_context_1, retrieval_context_2, retrieval_context_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output,
        retrieval_context=retrieval_context
    )

    test_cases.append(test_case)

# %%
result = evaluate(test_cases, [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))
# Out:
# ✨ You're running DeepEval's latest Faithfulness Metric! (using gpt-4o, strict=False, async_mode=False)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351849;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 22.62s | token cost: 0.014765000000000002 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 66.67% | Passed: 2 | Failed: 1
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Model output:", result.test_results[0].actual_output, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nRetrieval context:\n{test_result.retrieval_context}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Model output: We offer a 30-day full refund at no extra cost.
# =================================================================
#
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Retrieval context:
# ['All customers are eligible for a 30 day full refund at no extra cost.']
# ------------
# Reason:
# The score is 1.00 because there are no contradictions between the actual output and the retrieval context. Everything aligns perfectly, showcasing a high level of accuracy and consistency. Keep up the great work!
#
# ======
#
# score: 1.0
# threshold: 0.7
# success: True
# ------------
# Retrieval context:
# ['At our shop we sell shoes.']
# ------------
# Reason:
# The score is 1.00 because there are no contradictions between the actual output and the retrieval context. Everything aligns perfectly, showcasing a high level of accuracy and consistency. Great job!
#
# ======
#
# score: 0.0
# threshold: 0.7
# success: False
# ------------
# Retrieval context:
# ["It's not possible to offer any refund to the customer."]
# ------------
# Reason:
# The score is 0.00 because the actual output incorrectly claims a 30-day full refund is available, while the retrieval context clearly states that refunds are not offered to customers.
#
# ======

# %% [markdown]
# ### Podsumowanie metryk

# %% [markdown]
# | Nazwa metryki      | Zestawienie |
# |--------------------|---|
# | `ContextualPrecision`   | kolejność `retrieval_context` i `model_input` |
# | `ContextualRecall`      | `retrieval_context` i `expected_output` |
# | `ContextualRelevancy`   | `retrieval_context` i `model_input` |
# | `AnswerRelevancy`       | `actual_output` i `model_input`|
# | `Faithfulness`           | `actual_output` i `retrieval_context` |

# %% [markdown]
# ### Customowe metryki
#
# #### `GEval`
#
# Użyjemy `GEval` aby stworzyć własną metrykę o nazwie "Correctness", która porówna oczekiwaną oraz rzeczywistą odpowiedź modelu.

# %%
from deepeval.metrics import GEval
from deepeval.test_case import LLMTestCaseParams
# Out:
# /tmp/ipykernel_721881/2176520442.py:2: DeprecationWarning: 'LLMTestCaseParams' is deprecated and will be removed in a future release. Use 'SingleTurnParams' instead.
#   from deepeval.test_case import LLMTestCaseParams

# %%
metric = GEval(
        name="Correctness",
        criteria="""Determine if the 'actual output' is correct based on the 'expected output'.
                    Consider general sense of the answer and lack of contradictions. The answer doesn't need to be exactly the same""",
        evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
        threshold=0.7,
        model="gpt-4o"
    )


model_input = "It doesn't matter"
actual_output = "We offer a 30-day full refund at no extra cost."
expected_output_1 = "We offer a 15-day full refund at no extra cost."
expected_output_2 = "We offer a 30-day total refund with any additional payments."
expected_output_3 = "We don't offer any refund"



test_cases = []
for expected_output in [expected_output_1, expected_output_2, expected_output_3]:
    test_case = LLMTestCase(
        input=model_input,
        actual_output=actual_output,
        expected_output=expected_output
    )

    test_cases.append(test_case)

# %%
result = evaluate(test_cases, [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))
# Out:
# ✨ You're running DeepEval's latest Correctness [GEval] Metric! (using gpt-4o, strict=False, async_mode=False)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ⚠ WARNING: No hyperparameters logged.
# » ]8;id=9351851;https://deepeval.com/docs/evaluation-prompts\Log hyperparameters]8;;\ to attribute prompts and models to your test runs.
#
# ================================================================================
# ✓ Evaluation completed 🎉! (time taken: 7.45s | token cost: 0.006325000000000001 USD)
# » Test Results (3 total tests):
#    » Pass Rate: 33.33% | Passed: 1 | Failed: 2
#
#  ================================================================================
#
# » Want to share evals with your team, or a place for your test cases to live? ❤️ 🏡
#   » Run 'deepeval view' to analyze and save testing results on Confident AI.

# %%
print("Actual output:", result.test_results[0].actual_output, "\n=================================================================\n\n")

for test_result in result.test_results:
    metric_data = test_result.metrics_data[0]
    
    print(f"score: {metric_data.score}", f"threshold: {metric_data.threshold}", f"success: {metric_data.success}",
          f"------------\nExpected output::\n{test_result.expected_output}\n------------", f"Reason:\n{metric_data.reason}", sep="\n", end="\n\n======\n\n")
# Out:
# Actual output: We offer a 30-day full refund at no extra cost.
# =================================================================
#
#
# score: 0.6200710917769869
# threshold: 0.7
# success: False
# ------------
# Expected output::
# We offer a 15-day full refund at no extra cost.
# ------------
# Reason:
# The actual output conveys a similar meaning to the expected output by offering a full refund at no extra cost, but it contradicts the expected output by stating a 30-day period instead of a 15-day period. The key point of a refund policy is addressed, but the duration is inconsistent with the expected output.
#
# ======
#
# score: 0.7606106693876794
# threshold: 0.7
# success: True
# ------------
# Expected output::
# We offer a 30-day total refund with any additional payments.
# ------------
# Reason:
# The actual output closely aligns with the expected output, conveying the same general meaning of a 30-day refund policy. There are no contradictions, and the key point of a 30-day refund is addressed. However, the phrase 'at no extra cost' in the actual output slightly differs from 'with any additional payments' in the expected output, which could imply a different nuance regarding additional costs.
#
# ======
#
# score: 0.002128735416066125
# threshold: 0.7
# success: False
# ------------
# Expected output::
# We don't offer any refund
# ------------
# Reason:
# The actual output directly contradicts the expected output by stating a 30-day full refund is offered, whereas the expected output clearly states that no refund is offered. This contradiction fails to align with any of the evaluation steps, as the meanings are opposite and there is no logical consistency or coherence between the two outputs.
#
# ======

# %% [markdown]
# ## Ewaluacja RAGa – use case
#
# Use case na przykładzie `knowledge_database`

# %%
from qdrant_client import QdrantClient
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_qdrant import QdrantVectorStore
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_openai.chat_models import ChatOpenAI

# %%
client = QdrantClient(url="http://localhost:6333")

# %%
embeddings = HuggingFaceEmbeddings(model="sdadas/st-polish-paraphrase-from-distilroberta")

# %%
vector_store = QdrantVectorStore(
    client=client,
    collection_name="knowledge_database",
    embedding=embeddings,
)

retriever = vector_store.as_retriever(search_kwargs={"k": 4})
llm = ChatOpenAI(model="gpt-4o-mini")

# %%
template = """Retrieved documents:
---------
{context}

-----
End of retrieved documents
============

Answer the following question: {input}.

=============

Important information: You can answer only based on the context from the retrieved documents.
If you don't have any information regarding the question in the context, say 'I don't know'"""


prompt_template = PromptTemplate.from_template(template)

# %%
document_chain = create_stuff_documents_chain(llm, prompt_template)
retrieval_chain = create_retrieval_chain(retriever, document_chain)

# %% [markdown]
# ---

# %%
model_input = "Powiedz mi kto czym jeździ"
response = retrieval_chain.invoke({"input": model_input})

# %%
expected_output = "Andrzej jeździ samochodem, Bartek rowerem a Czarek tramwajem."
retrieval_context = [doc.page_content for doc in response["context"]]

# %%
retrieval_context

# %%
actual_output = response["answer"]
actual_output

# %% [markdown]
# ### Metryki

# %% [markdown]
# #### `ContextualPrecisionMetric`
#
# **Zestawiamy:** kolejność `retrieval_context` oraz `model_input`

# %%
metric = ContextualPrecisionMetric(
    threshold=0.7,
    model="gpt-4o"
)


test_case = LLMTestCase(
    input=model_input,
    actual_output=actual_output,
    expected_output=expected_output,
    retrieval_context=retrieval_context
)

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nModel input:\n{result.test_results[0].input}")
print(f"\nContext:\n{result.test_results[0].retrieval_context}")
print(f"\nReason:\n{metric_data.reason}")

# %% [markdown]
# #### `ContextualRecallMetric`
#
# **Zestawiamy:** `retrieval_context` oraz `expected_output`

# %%
metric = ContextualRecallMetric(
    threshold=0.7,
    model="gpt-4o"
)

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nExpected output:\n{result.test_results[0].expected_output}")
print(f"\nContext:\n{result.test_results[0].retrieval_context}")
print(f"\nReason:\n{metric_data.reason}")

# %% [markdown]
# #### `ContextualRelevancyMetric`
#
# **Zestawiamy:** `retrieval_context` oraz `model_input`

# %%
metric = ContextualRelevancyMetric(
    threshold=0.7,
    model="gpt-4o"
)

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nModel input:\n{result.test_results[0].input}")
print(f"\nContext:\n{result.test_results[0].retrieval_context}")
print(f"\nReason:\n{metric_data.reason}")

# %% [markdown]
# #### `AnswerRelevancyMetric`
#
# **Zestawiamy:** `actual_output` oraz `model_input`

# %%
metric = AnswerRelevancyMetric(
    threshold=0.7,
    model="gpt-4o"
)

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nModel input:\n{result.test_results[0].input}")
print(f"\nModel output:\n{result.test_results[0].actual_output}")
print(f"\nReason:\n{metric_data.reason}")

# %% [markdown]
# #### `FaithfulnessMetric`
#
# **Zestawiamy:** `retrieval_context` oraz `actual_output`

# %%
metric = FaithfulnessMetric(
    threshold=0.7,
    model="gpt-4o"
)

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nContext:\n{result.test_results[0].retrieval_context}")
print(f"\nModel output:\n{result.test_results[0].actual_output}")
print(f"\nReason:\n{metric_data.reason}")

# %% [markdown]
# #### `Correctness` (`GEval`)
#
# **Zestawiamy:** `actual_output` oraz `expected_output`

# %%
metric = GEval(
        name="Correctness",
        criteria="""Determine if the 'actual output' is correct based on the 'expected output'.
                    Consider general sense of the answer and lack of contradictions. The answer doesn't need to be exactly the same""",
        evaluation_params=[LLMTestCaseParams.ACTUAL_OUTPUT, LLMTestCaseParams.EXPECTED_OUTPUT],
        threshold=0.7,
        model="gpt-4o"
    )

# %%
result = evaluate([test_case], [metric],
                 async_config=AsyncConfig(run_async=False),
                 display_config=DisplayConfig(print_results=False))

# %%
metric_data = result.test_results[0].metrics_data[0]    

print(f"score: {metric_data.score}")
print(f"threshold: {metric_data.threshold}")
print(f"success: {metric_data.success}")
print(f"\nExpected output:\n{result.test_results[0].expected_output}")
print(f"\nModel output:\n{result.test_results[0].actual_output}")
print(f"\nReason:\n{metric_data.reason}")
